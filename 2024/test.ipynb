# %%
with open('input.txt') as f:
    data = f.read().splitlines()

# %%
tab = []
for line in data:
    tab.append(list(line))

# %%
def bfs(x, y, target, elements, visited):
    if (x, y) in visited:
        return False
    visited.append((x, y))
    if x < 0 or x >= len(tab) or y < 0 or y >= len(tab[0]) or tab[x][y] != target:
        return False
    elements.append((x, y))
    bfs(x-1, y, target, elements, visited)
    bfs(x+1, y, target, elements, visited)
    bfs(x, y-1, target, elements, visited)
    bfs(x, y+1, target, elements, visited)

# %%
# groups = []
# edges = []
# visited = []
# for i in range(len(tab)):
#     for j in range(len(tab[0])):
#         if (i, j) not in visited:
#             elements = []
#             bfs(i, j, tab[i][j], elements, [])
#             edge = []
#             for element in elements:
#                 if element[0] == 0 or (element[0]-1, element[1]) not in elements:
#                     edge.append(element)
#                 if element[0] == len(tab)-1 or (element[0]+1, element[1]) not in elements:
#                     edge.append(element)
#                 if element[1] == 0 or (element[0], element[1]-1) not in elements:
#                     edge.append(element)
#                 if element[1] == len(tab[0])-1 or (element[0], element[1]+1) not in elements:
#                     edge.append(element)
#             groups.append(elements)
#             edges.append(edge)
#             visited.extend(elements)

# %%
# price = 0
# for i in range(len(edges)):
#     price += len(edges[i]) * len(groups[i])
# print(price)

# %%
def turn_anticlockwise(dir):
    match dir:
        case (0, 1):
            return (-1, 0)
        case (0, -1):
            return (1, 0)
        case (1, 0):
            return (0, 1)
        case (-1, 0):
            return (0, -1)

def turn_clockwise(dir):
    match dir:
        case (0, 1):
            return (1, 0)
        case (0, -1):
            return (-1, 0)
        case (1, 0):
            return (0, -1)
        case (-1, 0):
            return (0, 1)

# %%
groups = []
sides = []
visited = []
for i in range(len(tab)):
    for j in range(len(tab[0])):
        if (i, j) not in visited:
            elements = []
            bfs(i, j, tab[i][j], elements, [])
            elements = sorted(elements)
            start = (elements[0][0] - 1, elements[0][1])
            def next_point(p, move, touch, starting=False):
                if not starting and p == start:
                    return 0
                if (p[0]+move[0], p[1]+move[1]) in elements:
                    return 1 + next_point(p, turn_anticlockwise(move), turn_anticlockwise(touch))
                else:
                    new_pos = (p[0]+move[0], p[1]+move[1])
                    touching = (new_pos[0]+touch[0], new_pos[1]+touch[1])
                    if touching in elements:
                        return next_point(new_pos, move, touch)
                    else:
                        new_move = turn_clockwise(move)
                        return 1 + next_point((new_pos[0]+new_move[0],new_pos[1]+new_move[1]), new_move, turn_clockwise(touch))
                
            nb_sides = next_point(start, (0, 1), (1, 0), True)   
            groups.append(elements)
            sides.append(nb_sides)
            visited.extend(elements)

# %%
sorted_groups = sorted(groups, key=lambda x: (len(x)))
for i, group in enumerate(sorted_groups):
    for j, other_group in enumerate(sorted_groups):
        if i != j and group[0][0] > other_group[0][0] and group[0][1] > other_group[0][1] and group[-1][0] < other_group[-1][0] and group[-1][1] < other_group[-1][1]:
            sides[j] += sides[i]

# %%
price = 0
for i in range(len(groups)):
    price += sides[i] * len(groups[i])
    print(groups[i][0], len(groups[i]), sides[i])
print(price)
# Out:
# (0, 0) 123 32
# (0, 9) 50 36
# (0, 19) 115 38
# (0, 29) 7 10
# (0, 33) 85 32
# (0, 47) 21 22
# (0, 52) 44 26
# (0, 58) 136 62
# (0, 68) 107 38
# (0, 77) 78 38
# (0, 80) 49 28
# (0, 100) 27 26
# (0, 104) 58 32
# (0, 111) 62 36
# (0, 117) 55 22
# (0, 125) 10 12
# (0, 127) 90 30
# (1, 86) 117 40
# (2, 76) 1 4
# (2, 91) 1 4
# (2, 109) 1 4
# (3, 41) 1 4
# (3, 43) 2 4
# (3, 49) 57 24
# (4, 31) 3 6
# (4, 63) 1 4
# (4, 101) 30 28
# (4, 106) 22 20
# (4, 139) 2 4
# (5, 75) 3 4
# (5, 95) 2 4
# (5, 135) 135 32
# (6, 8) 116 50
# (6, 32) 2 4
# (6, 35) 4 4
# (6, 38) 106 50
# (6, 51) 2 4
# (6, 118) 134 56
# (6, 133) 1 4
# (7, 27) 3 6
# (7, 96) 270 110
# (8, 19) 30 24
# (8, 29) 2 4
# (8, 53) 18 18
# (8, 68) 1 4
# (9, 5) 78 32
# (9, 19) 10 12
# (9, 27) 237 80
# (9, 31) 8 8
# (9, 106) 1 4
# (9, 113) 10 10
# (9, 117) 142 80
# (10, 63) 143 54
# (10, 67) 1 4
# (10, 96) 251 70
# (10, 103) 72 28
# (10, 115) 1 4
# (11, 24) 1 4
# (11, 76) 42 28
# (12, 52) 261 90
# (12, 82) 9 8
# (13, 103) 1 4
# (13, 117) 1 4
# (13, 119) 110 32
# (14, 19) 55 32
# (14, 36) 2 4
# (14, 48) 5 6
# (14, 66) 12 14
# (15, 9) 2 4
# (15, 19) 1 4
# (15, 68) 1 4
# (15, 84) 15 16
# (15, 100) 1 4
# (15, 112) 1 4
# (16, 5) 76 34
# (16, 74) 144 46
# (16, 101) 1 4
# (16, 109) 1 4
# (17, 34) 1 4
# (17, 74) 1 4
# (17, 110) 2 4
# (19, 24) 1 4
# (19, 83) 2 4
# (19, 108) 11 10
# (19, 133) 4 8
# (20, 13) 7 10
# (20, 14) 125 42
# (20, 32) 14 14
# (20, 130) 67 30
# (21, 26) 8 12
# (21, 127) 4 4
# (21, 135) 1 4
# (22, 137) 4 8
# (23, 31) 97 48
# (23, 36) 1 4
# (23, 56) 5 10
# (23, 127) 101 52
# (23, 129) 1 4
# (24, 21) 138 66
# (24, 29) 3 6
# (24, 78) 1 4
# (24, 111) 9 14
# (24, 112) 1 4
# (24, 115) 113 44
# (24, 130) 1 4
# (25, 38) 1 4
# (25, 54) 2 4
# (25, 128) 1 4
# (26, 0) 20 16
# (26, 3) 1 4
# (26, 60) 122 38
# (26, 75) 73 28
# (26, 125) 1 4
# (27, 50) 4 6
# (27, 57) 5 10
# (27, 111) 3 4
# (28, 55) 78 34
# (29, 8) 6 8
# (29, 28) 16 12
# (29, 95) 55 34
# (29, 123) 1 4
# (30, 1) 88 34
# (30, 50) 2 4
# (30, 56) 1 4
# (30, 108) 1 4
# (30, 126) 1 4
# (30, 135) 11 14
# (31, 15) 30 20
# (31, 17) 2 4
# (31, 30) 1 4
# (31, 118) 242 90
# (31, 124) 1 4
# (31, 138) 32 20
# (32, 9) 40 30
# (32, 38) 65 26
# (32, 59) 1 4
# (32, 126) 1 4
# (33, 12) 1 4
# (33, 33) 40 4
# (33, 58) 1 4
# (33, 82) 272 72
# (33, 100) 25 20
# (34, 51) 1 4
# (34, 79) 1 4
# (34, 87) 1 4
# (35, 58) 58 36
# (35, 71) 121 38
# (35, 112) 112 40
# (36, 16) 1 4
# (36, 73) 1 4
# (37, 1) 1 4
# (37, 15) 95 62
# (37, 17) 2 4
# (37, 18) 40 28
# (37, 20) 1 4
# (37, 90) 27 16
# (37, 101) 35 22
# (37, 102) 47 32
# (37, 115) 5 8
# (38, 96) 4 6
# (39, 9) 1 4
# (39, 31) 84 52
# (39, 46) 13 12
# (39, 51) 40 26
# (39, 76) 4 4
# (39, 89) 1 4
# (40, 38) 16 12
# (41, 65) 2 4
# (41, 95) 1 4
# (41, 120) 1 4
# (41, 128) 148 40
# (42, 14) 33 24
# (42, 43) 140 48
# (42, 58) 70 34
# (42, 89) 15 12
# (42, 107) 1 4
# (43, 20) 3 4
# (43, 52) 27 22
# (43, 95) 100 36
# (44, 129) 1 4
# (45, 9) 73 48
# (45, 22) 1 4
# (45, 46) 51 26
# (45, 115) 14 16
# (46, 1) 17 16
# (46, 14) 23 18
# (46, 64) 18 20
# (46, 105) 108 34
# (46, 127) 26 22
# (47, 48) 1 4
# (47, 108) 62 46
# (47, 115) 1 4
# (48, 50) 1 4
# (48, 52) 81 50
# (49, 27) 23 12
# (49, 60) 7 8
# (49, 71) 35 22
# (49, 90) 1 4
# (49, 123) 16 16
# (50, 12) 106 44
# (50, 21) 19 14
# (50, 66) 118 66
# (50, 91) 7 6
# (51, 16) 25 22
# (51, 44) 1 4
# (51, 46) 3 6
# (51, 76) 58 38
# (52, 3) 5 10
# (52, 15) 1 4
# (52, 19) 2 4
# (52, 37) 67 42
# (53, 0) 123 50
# (53, 61) 1 4
# (53, 90) 140 70
# (53, 96) 33 24
# (53, 120) 102 52
# (54, 8) 1 4
# (54, 50) 6 10
# (54, 54) 73 32
# (54, 73) 3 6
# (55, 17) 1 4
# (55, 23) 165 16
# (55, 42) 3 6
# (55, 44) 59 28
# (55, 60) 3 4
# (55, 80) 2 4
# (55, 118) 93 54
# (55, 135) 91 30
# (56, 31) 1 4
# (56, 51) 1 4
# (56, 72) 3 6
# (56, 81) 151 76
# (56, 112) 12 12
# (56, 137) 3 6
# (57, 44) 1 4
# (57, 84) 9 12
# (57, 130) 5 10
# (58, 9) 1 4
# (58, 20) 63 30
# (58, 22) 1 4
# (58, 67) 69 34
# (58, 112) 18 16
# (59, 15) 6 10
# (59, 19) 1 4
# (59, 88) 1 4
# (59, 105) 134 12
# (60, 73) 1 4
# (60, 79) 5 6
# (60, 116) 1 4
# (60, 138) 1 4
# (61, 48) 76 46
# (61, 130) 3 6
# (61, 132) 2 4
# (62, 73) 12 12
# (62, 76) 1 4
# (62, 94) 88 44
# (63, 14) 114 72
# (63, 37) 79 40
# (63, 122) 86 44
# (64, 15) 3 6
# (64, 68) 10 8
# (65, 72) 102 56
# (66, 17) 1 4
# (66, 73) 46 34
# (66, 101) 56 28
# (67, 2) 36 32
# (67, 15) 1 4
# (67, 21) 8 6
# (67, 52) 2 4
# (67, 57) 107 64
# (67, 76) 3 6
# (67, 132) 59 38
# (68, 38) 1 4
# (68, 45) 73 46
# (68, 46) 3 6
# (68, 52) 11 8
# (68, 89) 77 36
# (68, 133) 84 40
# (69, 0) 48 30
# (69, 29) 135 68
# (69, 51) 1 4
# (69, 61) 107 42
# (69, 82) 1 4
# (69, 90) 1 4
# (69, 127) 1 4
# (70, 64) 1 4
# (70, 83) 4 8
# (70, 135) 37 24
# (71, 7) 135 56
# (71, 33) 1 4
# (71, 106) 1 4
# (71, 133) 1 4
# (72, 1) 5 10
# (72, 8) 1 4
# (73, 74) 1 4
# (73, 110) 123 44
# (73, 111) 2 4
# (74, 5) 1 4
# (74, 42) 1 4
# (74, 102) 133 52
# (75, 23) 146 46
# (75, 78) 23 26
# (75, 92) 16 18
# (75, 124) 192 78
# (76, 37) 54 32
# (76, 57) 68 38
# (76, 59) 1 4
# (76, 91) 1 4
# (76, 95) 37 22
# (76, 96) 13 12
# (77, 82) 32 20
# (77, 89) 1 4
# (77, 94) 1 4
# (78, 121) 1 4
# (79, 75) 190 22
# (79, 89) 3 6
# (80, 14) 1 4
# (80, 17) 212 70
# (80, 82) 1 4
# (80, 99) 96 50
# (81, 18) 1 4
# (81, 49) 141 58
# (81, 89) 78 40
# (81, 91) 1 4
# (81, 100) 6 4
# (81, 131) 1 4
# (82, 65) 1 4
# (82, 119) 5 8
# (83, 4) 4 6
# (83, 34) 1 4
# (83, 63) 31 18
# (83, 98) 1 4
# (84, 30) 2 4
# (84, 41) 38 26
# (84, 42) 1 4
# (84, 49) 1 4
# (84, 73) 4 4
# (84, 92) 5 6
# (84, 116) 298 92
# (85, 25) 1 4
# (85, 34) 76 42
# (86, 20) 86 34
# (86, 79) 48 8
# (86, 113) 14 14
# (87, 18) 1 4
# (87, 57) 2 4
# (87, 60) 2 4
# (87, 75) 3 6
# (87, 77) 9 12
# (87, 93) 2 4
# (87, 125) 12 14
# (87, 131) 58 22
# (88, 10) 96 32
# (88, 95) 2 4
# (89, 25) 2 4
# (89, 28) 1 4
# (89, 45) 2 4
# (89, 69) 3 6
# (89, 78) 14 20
# (89, 80) 1 4
# (90, 7) 1 58
# (90, 37) 94 36
# (90, 38) 2 4
# (90, 60) 2 4
# (90, 62) 39 22
# (90, 75) 15 14
# (90, 96) 12 14
# (90, 97) 4 6
# (91, 44) 62 40
# (91, 47) 2 4
# (91, 67) 1 4
# (91, 68) 79 42
# (91, 113) 120 52
# (92, 65) 1 4
# (92, 81) 14 8
# (92, 88) 115 46
# (92, 101) 73 52
# (92, 125) 1 8
# (93, 49) 1 4
# (93, 124) 1 4
# (93, 131) 3 4
# (93, 134) 65 36
# (94, 15) 1 4
# (94, 25) 1 4
# (94, 28) 86 8
# (94, 58) 7 10
# (94, 65) 1 8
# (94, 77) 171 60
# (94, 90) 1 4
# (95, 22) 3 4
# (95, 25) 16 4
# (95, 105) 1 4
# (96, 16) 6 8
# (96, 22) 9 12
# (96, 57) 1 4
# (96, 68) 9 8
# (97, 22) 54 38
# (97, 50) 59 34
# (97, 120) 38 24
# (97, 121) 1 4
# (98, 10) 83 50
# (98, 13) 2 4
# (98, 15) 9 46
# (98, 60) 1 4
# (98, 88) 19 26
# (99, 46) 115 64
# (99, 98) 61 42
# (99, 114) 116 50
# (99, 117) 2 4
# (100, 45) 1 4
# (101, 6) 1 8
# (101, 88) 1 4
# (102, 13) 40 18
# (102, 43) 7 12
# (102, 58) 1 4
# (102, 94) 3 6
# (103, 23) 86 44
# (103, 39) 22 16
# (103, 62) 42 22
# (103, 88) 74 28
# (103, 97) 1 58
# (104, 28) 15 10
# (104, 34) 7 8
# (104, 58) 1 4
# (104, 64) 2 4
# (104, 109) 8 8
# (104, 123) 150 52
# (105, 24) 1 4
# (105, 44) 100 94
# (105, 96) 2 4
# (105, 104) 3 4
# (106, 9) 128 74
# (106, 32) 43 24
# (106, 59) 38 22
# (106, 99) 86 40
# (107, 68) 14 14
# (107, 70) 1 4
# (108, 71) 75 60
# (109, 110) 2 4
# (110, 85) 86 20
# (110, 129) 1 4
# (111, 4) 22 18
# (111, 16) 105 48
# (111, 37) 1 8
# (111, 55) 13 16
# (111, 65) 3 26
# (111, 67) 48 34
# (111, 95) 16 16
# (111, 119) 1 4
# (112, 22) 91 44
# (112, 38) 1 4
# (112, 70) 1 4
# (112, 110) 62 40
# (113, 8) 1 4
# (113, 28) 57 46
# (113, 50) 63 44
# (113, 58) 37 32
# (113, 70) 4 6
# (113, 104) 27 26
# (113, 108) 34 22
# (113, 109) 1 4
# (113, 120) 1 4
# (113, 137) 80 52
# (114, 1) 103 40
# (114, 26) 1 4
# (114, 69) 1 4
# (114, 76) 82 30
# (114, 79) 4 6
# (114, 83) 65 8
# (114, 92) 8 12
# (115, 14) 1 8
# (115, 42) 24 18
# (115, 45) 3 4
# (115, 112) 2 4
# (115, 122) 1 12
# (115, 138) 21 22
# (116, 7) 2 4
# (116, 79) 3 4
# (116, 97) 3 6
# (117, 12) 1 94
# (117, 59) 56 28
# (117, 66) 1 52
# (117, 96) 47 24
# (117, 106) 2 4
# (117, 107) 179 62
# (117, 136) 1 4
# (118, 92) 1 92
# (119, 41) 94 58
# (119, 51) 25 28
# (119, 60) 1 4
# (119, 138) 6 4
# (120, 0) 1 4
# (120, 47) 105 90
# (120, 81) 3 6
# (120, 92) 1 4
# (120, 100) 1 4
# (121, 12) 30 30
# (121, 36) 282 114
# (121, 68) 102 56
# (122, 82) 1 4
# (122, 108) 16 16
# (122, 124) 129 56
# (122, 132) 107 50
# (123, 57) 1 4
# (123, 61) 2 4
# (123, 76) 27 22
# (123, 82) 7 10
# (124, 8) 64 40
# (124, 38) 3 6
# (124, 40) 1 4
# (124, 66) 19 8
# (124, 90) 27 20
# (124, 97) 12 6
# (124, 137) 1 4
# (125, 0) 1 4
# (125, 15) 2 14
# (125, 21) 1 4
# (125, 72) 1 4
# (125, 73) 65 82
# (125, 84) 7 12
# (125, 108) 116 38
# (126, 4) 67 38
# (126, 20) 1 4
# (126, 65) 20 18
# (126, 81) 130 36
# (126, 91) 68 34
# (128, 7) 1 4
# (128, 47) 44 70
# (128, 68) 4 4
# (129, 85) 7 28
# (129, 108) 1 4
# (130, 25) 9 14
# (130, 36) 1 52
# (130, 43) 1 4
# (130, 69) 26 18
# (130, 90) 1 14
# (130, 95) 50 26
# (131, 75) 1 16
# (131, 123) 43 44
# (131, 124) 4 6
# (132, 3) 35 24
# (132, 7) 1 4
# (132, 28) 53 26
# (132, 31) 24 20
# (132, 48) 86 102
# (132, 105) 1 4
# (132, 136) 50 20
# (133, 66) 66 30
# (133, 96) 1 74
# (133, 105) 72 24
# (134, 10) 1 4
# (134, 86) 1 4
# (135, 42) 9 6
# (135, 54) 3 6
# (135, 62) 9 14
# (135, 130) 16 34
# (136, 0) 1 4
# (136, 94) 18 138
# (137, 12) 1 4
# (137, 74) 3 56
# (137, 87) 3 6
# (138, 125) 5 8
# (139, 0) 3 4
# (139, 5) 2 4
# (139, 131) 2 138
# 904498
